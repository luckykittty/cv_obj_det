# %%
from ultralytics import YOLO

# %%
cd /Users/katerinkak2002/Desktop/Учеба/ВКР
# Out:
# /Users/katerinkak2002/Desktop/Учеба/ВКР

# %%
cd datasets/Car-Space-Find-1
# Out:
# /Users/katerinkak2002/Desktop/Учеба/ВКР/datasets/Car-Space-Find-1

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="qVFp4WvB3pRdoDZrA6U1")
project = rf.workspace("tasarimproject").project("car-space-find")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.221, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Car-Space-Find-1 in yolov8:: 100%|█| 3052/3052

# %%
# Загрузить модель
model = YOLO('yolov8n.pt')  # загрузить предобученную модель (рекомендуется для обучения)

results = model.train(data='data.yaml', epochs=7, imgsz=640)
                      #, device='mps')
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.9 torch-2.1.1 CPU (Apple M1)
# ...

# %%
results
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x3066984f0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
# ...

# %%
# !yolo detect predict source='test/images' model='runs/detect/train7/weights/best.pt' imgsz=640
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.9 torch-2.1.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/21 /Users/katerinkak2002/Desktop/Учеба/ВКР/datasets/Car-Space-Find-1/test/images/2022-11-15-14-09-20_mp4-38_jpg.rf.3ad16ed293cc641721b5f749b61f51f4.jpg: 640x640 11 emptys, 6 occupieds, 99.7ms
# image 2/21 /Users/katerinkak2002/Desktop/Учеба/ВКР/datasets/Car-Space-Find-1/test/images/2022-11-15-14-11-26_mp4-37_jpg.rf.f1fa47b5f7ff059824c17d5674f08de2.jpg: 640x640 3 emptys, 4 occupieds, 70.6ms
# image 3/21 /Users/katerinkak2002/Desktop/Учеба/ВКР/datasets/Car-Space-Find-1/test/images/4k-time-lapse-car-parking-lot-stock-video-download-video-clip-now-istock_TyROSAGZ_mp4-117_jpg.rf.c0d667d88dde2f5101086c38cd349dba.jpg: 640x640 15 emptys, 43 occupieds, 73.7ms
# ...

# %%
# !yolo detect train data='data.yaml' model=yolov8n.pt epochs=7 imgsz=640 batch=8 
#device=mps
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.9 torch-2.1.1 CPU (Apple M1)
# ...

# %%
# !yolo detect train data='data.yaml' model=yolov8m.pt epochs=7 imgsz=640 batch=8
# Out:
# ...
# 100%|██████████████████████████████████████| 49.7M/49.7M [00:16<00:00, 3.15MB/s]
# New https://pypi.org/project/ultralytics/8.0.225 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.9 torch-2.1.1 CPU (Apple M1)
# ...

# %%
dataset.location
# Out:
# '/Users/katerinkak2002/Desktop/Учеба/ВКР/Car-Space-Find-1'
