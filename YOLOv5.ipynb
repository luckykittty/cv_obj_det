# %%
import torch
import pandas as pd
import os
import numpy as np
import shutil
import ast
from sklearn import model_selection
from tqdm import tqdm
import wandb
from sklearn.model_selection import GroupKFold
from IPython.display import Image, clear_output  # to display images
from os import listdir
from os.path import isfile
from glob import glob
import yaml
# clear_output()

# %%
import comet_ml
comet_ml.init(project_name='comet-example-yolov5')

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install -U -r yolov5/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.4/660.4 kB 1.2 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.3
#     Uninstalling pandas-2.1.3:
#       Successfully uninstalled pandas-2.1.3
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.221
#     Uninstalling ultralytics-8.0.221:
#       Successfully uninstalled ultralytics-8.0.221
# ...

# %%
cd /Users/katerinkak2002/Desktop/Учеба/ВКР/yolov5
# Out:
# /Users/katerinkak2002/Desktop/Учеба/ВКР/yolov5

# %%
# !python train.py \
--img 640 \
--batch 8 \
--epochs 7 \
--data Parking-Space-2/data.yaml \
--weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: katerinkak2002 (force_). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=Parking-Space-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=7, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# ...

# %%
# !python detect.py \
--img 256 \
--weights runs/train/exp14/weights/best.pt\
--source Parking-Space-4/test/images
# Out:
# detect: weights=['runs/train/exp14/weights/best.pt'], source=Parking-Space-4/test/images, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.9 torch-2.1.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/226 /Users/katerinkak2002/Desktop/Учеба/ВКР/yolov5/Parking-Space-4/test/images/00000301_jpg.rf.29c98c74a995211b2d5c8b879129ff88.jpg: 256x256 6 occupieds, 28.7ms
# ...

# %%
# !python train.py \
--img 640 \
--batch 8 \
--epochs 10 \
--data Car-Space-Find-1/data.yaml \
--weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: katerinkak2002 (force_). Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=Car-Space-Find-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.9 torch-2.1.1 CPU
#
# ...

# %%
# !python detect.py \
--img 640 \
--weights runs/train/exp17/weights/best.pt\
--source Car-Space-Find-1/test/images
# Out:
# detect: weights=['runs/train/exp17/weights/best.pt'], source=Car-Space-Find-1/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=True, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-247-g3f02fde Python-3.10.9 torch-2.1.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/21 /Users/katerinkak2002/Desktop/Учеба/ВКР/yolov5/Car-Space-Find-1/test/images/2022-11-15-14-09-20_mp4-38_jpg.rf.3ad16ed293cc641721b5f749b61f51f4.jpg: 640x640 13 emptys, 4 occupieds, 125.0ms
# ...

# %%
# %pip install comet_ml --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import wandb
wandb.init(
    # set the wandb project where this run will be logged
    project="my-awesome-project")
